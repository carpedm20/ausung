# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import json
with open('./user_data4.txt') as f:
    j=json.loads(f.read())

# %%
ak = [item['doc_count'] for item in j['aggregations']['my_agg']['buckets'] if item['doc_count'] > 100]

# %%
len(ak)
# Out:
# 490446

# %%
k = [item['doc_count'] for item in j['aggregations']['my_agg']['buckets'] if item['doc_count'] > 500]

# %%
plt.hist(ak, 1000)
# Out:
# (array([  6.02500000e+03,   4.59900000e+03,   4.55500000e+03,
#          3.46800000e+03,   3.17800000e+03,   3.16900000e+03,
#          2.54700000e+03,   2.23800000e+03,   2.39200000e+03,
#          1.88600000e+03,   1.75800000e+03,   1.80500000e+03,
#          1.44700000e+03,   1.39300000e+03,   1.35400000e+03,
#          1.20600000e+03,   1.07100000e+03,   1.12600000e+03,
#          9.41000000e+02,   8.91000000e+02,   9.52000000e+02,
#          7.79000000e+02,   7.20000000e+02,   7.66000000e+02,
#          6.64000000e+02,   5.93000000e+02,   6.29000000e+02,
#          5.31000000e+02,   5.55000000e+02,   5.74000000e+02,
#          4.87000000e+02,   4.93000000e+02,   5.03000000e+02,
#          4.14000000e+02,   4.24000000e+02,   3.92000000e+02,
#          3.83000000e+02,   3.63000000e+02,   3.32000000e+02,
#          3.01000000e+02,   3.22000000e+02,   2.61000000e+02,
#          2.84000000e+02,   2.92000000e+02,   2.63000000e+02,
# ...

# %%
a = [2, 5, 7]
plt.hist(a)
# Out:
# (array([ 1.,  0.,  0.,  0.,  0.,  0.,  1.,  0.,  0.,  1.]),
#  array([ 2. ,  2.5,  3. ,  3.5,  4. ,  4.5,  5. ,  5.5,  6. ,  6.5,  7. ]),
#  <a list of 10 Patch objects>)

# %%
k[0]
# Out:
# 8444
